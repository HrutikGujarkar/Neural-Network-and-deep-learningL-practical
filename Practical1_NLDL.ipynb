# %% [markdown]
# <a href="https://colab.research.google.com/github/HrutikGujarkar/Neural-Network-and-deep-learningL-practical/blob/main/Practical1_NLDL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
vector1=np.array([3,4,6,7,8])

# %%
vector2=np.array([7,5,44,67,34])

# %%
print(vector1)
# Out:
# [3 4 6 7 8]

# %%
print(vector2)
# Out:
# [ 7  5 44 67 34]

# %%
result=vector1+vector2
print(result)
# Out:
# [10  9 50 74 42]

# %%
MatrixA=np.array([[2,4,5,6],[3,6,7,4],[35,7,8,6]])

# %%
MatrixB=np.array([[2,4,5,8],[3,4,6,8],[9,2,5,9],[6,7,8,5]])

# %%
print(MatrixA)
# Out:
# [[ 2  4  5  6]
#  [ 3  6  7  4]
#  [35  7  8  6]]

# %%
print(MatrixB)
# Out:
# [[2 4 5 8]
#  [3 4 6 8]
#  [9 2 5 9]
#  [6 7 8 5]]

# %%
Matrix_Multiplication=np.matmul(MatrixA,MatrixB)

# %%
print(Matrix_Multiplication)
# Out:
# [[ 97  76 107 123]
#  [111  78 118 155]
#  [199 226 305 438]]
